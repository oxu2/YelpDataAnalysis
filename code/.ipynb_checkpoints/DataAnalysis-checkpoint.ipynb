# %%
import pandas as pd
import collections 
import matplotlib as plt


business = pd.read_csv('../sandwiches.csv')
review = pd.read_csv('../sandwiches_review.csv')

# %%
### DATA SUMMARY
print(business.loc[1])
# Out:
# Unnamed: 0                                                      1
# business_id                                jGennaZUr2MsJyRhijNBfA
# name                                              Legal Sea Foods
# address                                           1 Harborside Dr
# city                                                       Boston
# state                                                          MA
# postal_code                                                 02128
# latitude                                                42.363442
# longitude                                              -71.025781
# stars                                                         3.5
# review_count                                                  856
# is_open                                                         1
# attributes      {'NoiseLevel': "u'average'", 'BikeParking': 'F...
# categories      Sandwiches, Food, Restaurants, Breakfast & Bru...
# hours           {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...
# Name: 1, dtype: object

# %%
print(review.loc[1])
# Out:
# Unnamed: 0                                                      1
# review_id                                  8IkgIe8Ih9_kGPONsGyRKw
# user_id                                    78G0GrPhgdh2hRHly3L2gQ
# business_id                                DbXHNl890xSXNiyRczLWAg
# stars_x                                                       5.0
# useful                                                          0
# funny                                                           0
# cool                                                            0
# text            You've gotta try this place. We went for brunc...
# date                                          2018-06-09 20:30:29
# Unnamed: 0.1                                                  123
# name                                                Orlando Meats
# address                                 1035 Orlando Ave, Ste 105
# city                                                  Winter Park
# state                                                          FL
# postal_code                                                 32789
# latitude                                                28.606844
# longitude                                              -81.365592
# stars_y                                                       4.5
# review_count                                                  187
# is_open                                                         1
# attributes      {'BikeParking': 'True', 'RestaurantsPriceRange...
# categories      Butcher, Brazilian, Argentine, Restaurants, Sa...
# hours           {'Monday': '0:0-0:0', 'Tuesday': '8:0-20:0', '...
# Name: 1, dtype: object

# %%
print(business.groupby(['state'])['business_id'].count())
# Out:
# state
# BC     654
# CO     135
# FL    1154
# GA     856
# MA    1891
# OH     719
# OR    1025
# TX     735
# WA     103
# Name: business_id, dtype: int64

# %%
# business.head()

# %%
# review['text'].tolist()

# %%
print(business.groupby(['state'])['review_count'].sum())
# Out:
# state
# BC     29480
# CO     12768
# FL     94128
# GA     91671
# MA    197817
# OH     39346
# OR    116833
# TX    112443
# WA      6459
# Name: review_count, dtype: int64

# %%
stars_average_state = business.groupby(['state'])['stars'].mean()
stars_average_state
# Out:
# state
# BC    3.520642
# CO    3.544444
# FL    3.621317
# GA    3.358645
# MA    3.512956
# OH    3.356745
# OR    3.749756
# TX    3.584354
# WA    3.480583
# Name: stars, dtype: float64

# %%
import matplotlib.pyplot as plt
import geopandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/pn/hckqkf296kg0zy4dv62c5sk40000gn/T/ipykernel_76394/1157427032.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 import geopandas
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
### RESTRANUANT SCORE
res_score = business.groupby(['name'])['stars'].mean()
res_count = review.groupby(['name'])['name'].count()

res_score.sort_values()
res_count.sort_values()


### TO SEE THE OVERALL CATEGORIES FREQUENCY
def word_order(dataframe,separator):
    text = []
    for i in list(dataframe):
        j = i.split(separator)
        for k in j:
            text.append(k)
    word_counts = collections.Counter(text)
    return sorted(word_counts.items(),key=lambda x:x[1],reverse=True)


word_order(review['categories'], ', ')

# %%
### TO SEE THE CATEGORIES FREQUENCY BY SOCRE
word_order(review[review['stars_y']>=4]['categories'], ', ')
word_order(review[review['stars_y']<=2]['categories'], ', ')

# %%
### TO SEE THE WORD FREQUENCY BY SOCRE
word_order(review[review['stars_x']>=4]['text'], ' ')
word_order(review[review['stars_x']<=2]['text'], ' ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pn/hckqkf296kg0zy4dv62c5sk40000gn/T/ipykernel_76264/1332320017.py in <module>
#       1 ### TO SEE THE WORD FREQUENCY BY SOCRE
# ----> 2 word_order(review[review['stars_x']>=4]['text'], ' ')
#       3 word_order(review[review['stars_x']<=2]['text'], ' ')
#       4
#
# NameError: name 'word_order' is not defined

# %%
### Analysis: Reasons of abnorm review
good_to_bad = review[(review['stars_y']<2)&(review['stars_x']>4)]['text']
bad_to_good = review[(review['stars_y']>4)&(review['stars_x']<2)]['text']
word_order(good_to_bad, ' ')
word_order(bad_to_good, ' ')
# Out:
# [('the', 23621),
#  ('and', 18334),
#  ('I', 16300),
#  ('to', 16266),
#  ('a', 13148),
#  ('was', 10958),
#  ('', 8011),
#  ('of', 7997),
#  ('for', 6594),
#  ('in', 6090),
#  ('it', 5522),
#  ('that', 5368),
#  ('is', 4937),
#  ('my', 4847),
#  ('not', 4500),
#  ('this', 4136),
#  ('they', 4008),
#  ('with', 3841),
#  ('on', 3793),
#  ('but', 3789),
#  ('we', 3524),
#  ('The', 3410),
#  ('have', 3381),
#  ('at', 3332),
#  ('had', 3256),
#  ('were', 3151),
#  ('you', 3144),
#  ('be', 3062),
#  ('food', 2679),
#  ('so', 2470),
#  ('me', 2437),
#  ('place', 2132),
#  ('like', 2002),
#  ('as', 1942),
#  ('are', 1936),
#  ('just', 1936),
#  ('there', 1832),
#  ('out', 1814),
#  ('our', 1798),
#  ('from', 1732),
#  ('no', 1722),
#  ('up', 1689),
#  ('get', 1682),
#  ('or', 1673),
#  ('their', 1663),
#  ('We', 1646),
#  ('if', 1642),
#  ('an', 1629),
#  ('order', 1592),
#  ('would', 1591),
#  ('one', 1562),
#  ('about', 1547),
#  ('when', 1497),
#  ('all', 1464),
#  ('your', 1427),
#  ('he', 1351),
#  ('time', 1351),
#  ('because', 1346),
#  ('got', 1297),
#  ('go', 1280),
#  ('very', 1274),
#  ('ordered', 1269),
#  ('even', 1267),
#  ('will', 1260),
#  ('back', 1248),
#  ('been', 1232),
#  ('what', 1228),
#  ('good', 1227),
#  ('she', 1209),
#  ("don't", 1184),
#  ('only', 1140),
#  ('us', 1124),
#  ('here', 1116),
#  ('said', 1115),
#  ('after', 1070),
#  ("didn't", 1062),
#  ('service', 1040),
#  ('never', 1034),
#  ('asked', 1010),
#  ('by', 1002),
#  ('over', 994),
#  ('people', 979),
#  ('It', 968),
#  ('could', 959),
#  ('told', 946),
#  ('them', 934),
#  ('sandwich', 915),
#  ('minutes', 910),
#  ('which', 900),
#  ('They', 894),
#  ('came', 893),
#  ('This', 892),
#  ("I'm", 889),
#  ('some', 882),
#  ('then', 869),
#  ('other', 858),
#  ('really', 847),
#  ('her', 844),
#  ('more', 832),
#  ('can', 828),
#  ('who', 825),
#  ('went', 821),
#  ('how', 807),
#  ('make', 783),
#  ("it's", 778),
#  ('do', 774),
#  ('it.', 753),
#  ('did', 753),
#  ('know', 748),
#  ('going', 713),
#  ('My', 697),
#  ('before', 682),
#  ('customer', 682),
#  ('has', 680),
#  ('than', 678),
#  ('first', 657),
#  ('wait', 648),
#  ('any', 648),
#  ('-', 644),
#  ('way', 634),
#  ('eat', 633),
#  ('want', 629),
#  ('come', 626),
#  ('restaurant', 625),
#  ('two', 612),
#  ("I've", 611),
#  ('his', 608),
#  ('try', 606),
#  ('take', 605),
#  ('made', 597),
#  ('give', 579),
#  ('much', 575),
#  ('chicken', 575),
#  ('should', 566),
#  ('food.', 563),
#  ('too', 551),
#  ('bad', 546),
#  ('coffee', 546),
#  ('say', 545),
#  ('better', 542),
#  ('off', 539),
#  ('another', 537),
#  ('took', 536),
#  ('being', 534),
#  ('cheese', 534),
#  ('also', 533),
#  ('Not', 519),
#  ("wasn't", 516),
#  ('wanted', 510),
#  ('ever', 508),
#  ('If', 507),
#  ('i', 507),
#  ('line', 506),
#  ('pizza', 504),
#  ('When', 500),
#  ('staff', 495),
#  ('owner', 486),
#  ('waiting', 481),
#  ('am', 480),
#  ('still', 477),
#  ('2', 473),
#  ('great', 465),
#  ('down', 464),
#  ('experience', 457),
#  ('She', 456),
#  ('put', 445),
#  ('think', 444),
#  ('table', 443),
#  ('So', 434),
#  ('And', 433),
#  ('He', 431),
#  ('meat', 431),
#  ('long', 430),
#  ('left', 428),
#  ('rude', 422),
#  ('since', 420),
#  ('where', 420),
#  ('business', 418),
#  ('back.', 417),
#  ('few', 413),
#  ('while', 412),
#  ('taste', 412),
#  ('walked', 408),
#  ('see', 407),
#  ('something', 406),
#  ('hour', 404),
#  ('around', 404),
#  ('last', 401),
#  ('customers', 400),
#  ('called', 397),
#  ('tried', 394),
#  ('tasted', 391),
#  ('sure', 388),
#  ("can't", 387),
#  ('menu', 386),
#  ("won't", 384),
#  ('right', 383),
#  ('money', 381),
#  ('3', 380),
#  ('into', 380),
#  ('small', 380),
#  ('half', 379),
#  ('reviews', 377),
#  ('waited', 376),
#  ('place.', 375),
#  ('same', 374),
#  ('times', 370),
#  ('little', 364),
#  ('But', 360),
#  ('No', 357),
#  ('him', 356),
#  ('bread', 356),
#  ('worth', 356),
#  ('why', 355),
#  ('ask', 355),
#  ('counter', 353),
#  ('There', 353),
#  ('new', 347),
#  ('decided', 339),
#  ('guy', 339),
#  ('salad', 337),
#  ('many', 336),
#  ('&', 334),
#  ('actually', 333),
#  ('open', 332),
#  ('me.', 331),
#  ('service.', 328),
#  ('without', 327),
#  ('again', 324),
#  ("couldn't", 324),
#  ("It's", 322),
#  ('You', 322),
#  ('looked', 321),
#  ('again.', 321),
#  ('nothing', 321),
#  ('server', 321),
#  ('here.', 320),
#  ('find', 320),
#  ('tell', 319),
#  ('gave', 318),
#  ('someone', 318),
#  ('sandwiches', 317),
#  ('order.', 317),
#  ('worst', 316),
#  ('now', 315),
#  ('next', 315),
#  ('5', 311),
#  ('After', 311),
#  ('thing', 307),
#  ('love', 305),
#  ('until', 305),
#  ('day', 305),
#  ('eating', 298),
#  ('anything', 298),
#  ('breakfast', 296),
#  ('disappointed', 294),
#  ('away', 293),
#  ('most', 292),
#  ('sauce', 292),
#  ('coming', 291),
#  ('meal', 291),
#  ('pretty', 290),
#  ('front', 288),
#  ('thought', 285),
#  ('manager', 285),
#  ('person', 284),
#  ('cold', 284),
#  ('review', 281),
#  ('looking', 280),
#  ('lunch', 279),
#  ('work', 279),
#  ('good.', 277),
#  ('always', 273),
#  ('10', 272),
#  ('feel', 269),
#  ('let', 268),
#  ('need', 268),
#  ('food,', 267),
#  ('A', 266),
#  ('quality', 265),
#  ('\n\nI', 264),
#  ('pay', 263),
#  ("doesn't", 261),
#  ('getting', 260),
#  ('least', 255),
#  ('call', 254),
#  ('used', 253),
#  ('hard', 253),
#  ('these', 252),
#  ('trying', 252),
#  ('nice', 250),
#  ("that's", 247),
#  ('behind', 246),
#  ("you're", 246),
#  ('extremely', 245),
#  ('4', 245),
#  ('waitress', 245),
#  ('best', 244),
#  ('recommend', 244),
#  ('phone', 244),
#  ('every', 244),
#  ('out.', 244),
#  ('time.', 244),
#  ('both', 242),
#  ('hot', 242),
#  ('finally', 240),
#  ('served', 240),
#  ('20', 239),
#  ('hours', 236),
#  ('ordering', 235),
#  ('almost', 234),
#  ("wouldn't", 233),
#  ('well', 230),
#  ('friend', 230),
#  ('felt', 229),
#  ('found', 228),
#  ('enough', 228),
#  ('understand', 227),
#  ('such', 227),
#  ('paid', 226),
#  ('whole', 225),
#  ('side', 225),
#  ('leave', 225),
#  ('look', 224),
#  ('today', 224),
#  ('different', 223),
#  ('things', 222),
#  ("I'll", 222),
#  ('employees', 222),
#  ('check', 221),
#  ('pick', 221),
#  ('else', 220),
#  ('received', 220),
#  ('it,', 219),
#  ('saw', 219),
#  ('orders', 218),
#  ('its', 218),
#  ('top', 217),
#  ('sandwich.', 217),
#  ('Food', 216),
#  ('Very', 216),
#  ('lot', 215),
#  ('there.', 213),
#  ('having', 213),
#  ('.', 212),
#  ('three', 212),
#  ('What', 212),
#  ('old', 212),
#  ('home', 212),
#  ('making', 211),
#  ('30', 211),
#  ('tables', 210),
#  ('through', 209),
#  ('door', 208),
#  ('already', 208),
#  ('serve', 208),
#  ('1', 207),
#  ('though', 206),
#  ('definitely', 206),
#  ('saying', 206),
#  ('NOT', 206),
#  ('drink', 206),
#  ('wrong', 205),
#  ('everything', 205),
#  ('As', 205),
#  ('seemed', 204),
#  ('husband', 203),
#  ('Then', 203),
#  ('star', 203),
#  ('beef', 203),
#  ('Just', 202),
#  ('flavor', 198),
#  ('maybe', 198),
#  ('probably', 197),
#  ('places', 196),
#  ('price', 196),
#  ('super', 195),
#  ('waste', 195),
#  ('couple', 195),
#  ('us.', 194),
#  ('extra', 194),
#  ('15', 194),
#  ('dry', 193),
#  ('BBQ', 192),
#  ('sitting', 192),
#  ('walk', 191),
#  ('friends', 191),
#  ('sit', 190),
#  ('completely', 190),
#  ('kind', 189),
#  ('close', 189),
#  ('care', 188),
#  ('instead', 187),
#  ('use', 187),
#  ('given', 187),
#  ("isn't", 186),
#  ('brought', 186),
#  ('busy', 186),
#  ('sat', 184),
#  ('girl', 184),
#  ('bit', 182),
#  ('says', 180),
#  ('arrived', 180),
#  ('fries', 180),
#  ('once', 180),
#  ('family', 179),
#  ('sub', 179),
#  ('outside', 178),
#  ('ate', 178),
#  ('ended', 177),
#  ('guess', 177),
#  ('working', 177),
#  ('several', 177),
#  ('good,', 177),
#  ('wife', 177),
#  ('disappointed.', 177),
#  ('big', 177),
#  ('all.', 176),
#  ("I'd", 176),
#  ('pork', 176),
#  ('everyone', 175),
#  ("Don't", 175),
#  ('lady', 174),
#  ('excited', 174),
#  ('experience.', 174),
#  ('up.', 173),
#  ('believe', 172),
#  ('later', 172),
#  ('poor', 172),
#  ('employee', 171),
#  ('full', 171),
#  ('literally', 171),
#  ('high', 170),
#  ('brisket', 169),
#  ('free', 169),
#  (',', 168),
#  ('cooked', 167),
#  ('them.', 167),
#  ('terrible', 167),
#  ('second', 167),
#  ('In', 166),
#  ('plate', 164),
#  ('taking', 164),
#  ('inside', 164),
#  ('water', 164),
#  ('attitude', 164),
#  ('less', 163),
#  ('anyone', 163),
#  ('man', 163),
#  ('those', 163),
#  ('point', 163),
#  ('may', 161),
#  ('\n\nThe', 161),
#  ('One', 158),
#  ('burger', 157),
#  ('shop', 156),
#  ('must', 156),
#  ('years', 155),
#  ('does', 154),
#  ('location', 154),
#  ('cashier', 154),
#  ('woman', 152),
#  ('absolutely', 151),
#  ('away.', 151),
#  ('restaurant.', 151),
#  ('Ordered', 151),
#  ('bar', 151),
#  ('egg', 151),
#  ('done', 150),
#  ('each', 150),
#  ('order,', 150),
#  ('Maybe', 149),
#  ('fresh', 148),
#  ('charge', 148),
#  ('supposed', 147),
#  ('own', 147),
#  ('ready', 146),
#  ('soup', 146),
#  ('party', 146),
#  ('rather', 145),
#  ('fried', 145),
#  ('sign', 145),
#  ('heard', 144),
#  ('minutes.', 144),
#  ('closed', 144),
#  ('drinks', 144),
#  ('eggs', 144),
#  ('steak', 143),
#  ('fact', 143),
#  ('store', 143),
#  ('That', 142),
#  ('large', 142),
#  ('able', 142),
#  ('started', 142),
#  ('seated', 142),
#  ('reason', 141),
#  ('kitchen', 141),
#  ('entire', 141),
#  ('Went', 141),
#  ('visit', 138),
#  ('real', 138),
#  ('For', 138),
#  ('night', 138),
#  ('time,', 137),
#  ('makes', 137),
#  ('name', 137),
#  ('First', 137),
#  ('cup', 137),
#  ('gone', 136),
#  ('45', 136),
#  ('far', 136),
#  ('based', 135),
#  ('bring', 135),
#  ('friendly', 135),
#  ('items', 135),
#  ('vegan', 135),
#  ('seem', 134),
#  ('kept', 134),
#  ('me,', 134),
#  ('part', 133),
#  ('cut', 132),
#  ('keep', 132),
#  ('during', 131),
#  ('customers.', 131),
#  ('dinner', 130),
#  ('horrible', 130),
#  ('business.', 130),
#  ('offered', 130),
#  ('bite', 130),
#  ('At', 130),
#  ('help', 130),
#  ("they're", 130),
#  ('drive', 129),
#  ('paying', 129),
#  ('hope', 129),
#  ('due', 128),
#  ('area', 128),
#  ('live', 128),
#  ('cook', 127),
#  ('sausage', 127),
#  ('hair', 127),
#  ('bagel', 127),
#  ('comes', 126),
#  ('place,', 125),
#  ('seems', 125),
#  ('mediocre', 125),
#  ('slice', 125),
#  ('left.', 125),
#  ('cream', 125),
#  ('opened', 125),
#  ('return', 124),
#  ('Never', 124),
#  ('might', 124),
#  ('reviews.', 124),
#  ("weren't", 124),
#  ('owners', 124),
#  ('asking', 123),
#  ('problem', 123),
#  ('piece', 123),
#  ('table.', 122),
#  ('past', 122),
#  ('noticed', 122),
#  ('buy', 122),
#  ('restaurants', 121),
#  ('week', 121),
#  ('special', 120),
#  ('else.', 120),
#  ('tip', 120),
#  ('amount', 120),
#  ('usually', 120),
#  ('across', 120),
#  ('quite', 120),
#  ('that.', 120),
#  ('doing', 119),
#  ('expect', 119),
#  ('offer', 119),
#  ('turned', 119),
#  ('delivery', 119),
#  ('especially', 118),
#  ('service,', 118),
#  ('simple', 117),
#  ('All', 117),
#  ('giving', 117),
#  ('enjoy', 117),
#  ('huge', 117),
#  ('looks', 117),
#  ('here,', 116),
#  ('placed', 116),
#  ('Was', 116),
#  ('soggy', 116),
#  ('bacon', 116),
#  ('longer', 115),
#  ('needed', 115),
#  ('start', 115),
#  ('dining', 115),
#  ('options', 114),
#  ('6', 114),
#  ('group', 114),
#  ('said,', 113),
#  ('clearly', 113),
#  ('--', 113),
#  ('ok', 112),
#  ('burnt', 112),
#  ('myself', 112),
#  ('talk', 112),
#  ('sorry', 112),
#  ('barely', 111),
#  ('Yelp', 111),
#  ('Austin', 111),
#  ('To', 111),
#  ('lack', 111),
#  ('rice', 111),
#  ('stars', 110),
#  ('add', 110),
#  ('online', 110),
#  ('local', 110),
#  ('bland', 110),
#  ('empty', 109),
#  ('single', 109),
#  ('under', 109),
#  ('prices', 109),
#  ('terrible.', 109),
#  ('potato', 109),
#  ('treated', 109),
#  ('stop', 108),
#  ('sweet', 108),
#  ('disappointing', 108),
#  ('in.', 108),
#  ('morning', 108),
#  ('refund', 107),
#  ('waiter', 107),
#  ('How', 107),
#  ('wait.', 106),
#  ('Even', 106),
#  ('run', 106),
#  ('days', 106),
#  ('boyfriend', 105),
#  ('forgot', 105),
#  ('out,', 105),
#  ('pieces', 105),
#  ('establishment', 105),
#  ('read', 104),
#  ('stopped', 104),
#  ('Their', 104),
#  ('Will', 104),
#  ('sandwich,', 104),
#  ('charged', 104),
#  ('regular', 104),
#  ('eaten', 104),
#  ('\nI', 103),
#  ('somewhere', 102),
#  ('card', 102),
#  ('lobster', 102),
#  ('mention', 102),
#  ('serving', 102),
#  ('standing', 102),
#  ('white', 102),
#  ('rude.', 102),
#  ('response', 102),
#  ('either', 101),
#  ('idea', 101),
#  ('wish', 101),
#  ('again,', 101),
#  ('lost', 101),
#  ('ahead', 100),
#  ('happened', 100),
#  ('happy', 100),
#  ('twice', 99),
#  ('However,', 99),
#  ('deal', 99),
#  ('drove', 99),
#  ('mind', 99),
#  ('year', 99),
#  ('mins', 99),
#  ('dirty', 99),
#  ('coffee.', 99),
#  ('well.', 98),
#  ('register', 98),
#  ('immediately', 98),
#  ('mean', 98),
#  ('menu.', 98),
#  ('sick', 98),
#  ('min', 97),
#  ('talking', 97),
#  ('cost', 97),
#  ('money.', 97),
#  ('bbq', 97),
#  ('stand', 96),
#  ('needs', 96),
#  ('bread.', 96),
#  ('town', 96),
#  ('grab', 96),
#  ('meal.', 96),
#  ('beer', 96),
#  ('awful', 96),
#  ('bad.', 95),
#  ('walking', 95),
#  ("That's", 95),
#  ('black', 95),
#  ('day.', 95),
#  ('flavor.', 94),
#  ('expensive', 94),
#  ('off.', 94),
#  ('finish', 94),
#  ('there,', 94),
#  ('taken', 94),
#  ('dish', 94),
#  ('spend', 93),
#  ('write', 93),
#  ('treat', 93),
#  ('minute', 93),
#  ('back,', 93),
#  ('picked', 92),
#  ('fine', 92),
#  ('go.', 92),
#  ('rest', 92),
#  ('Had', 92),
#  ('threw', 92),
#  ('simply', 92),
#  ('hungry', 91),
#  ('Also', 91),
#  ('you.', 91),
#  ('tea', 91),
#  ('type', 91),
#  ('overpriced', 91),
#  ('grilled', 91),
#  ('forward', 90),
#  ('four', 90),
#  ('guys', 90),
#  ('hand', 90),
#  ('number', 90),
#  ('spent', 90),
#  ('spot', 90),
#  ('down.', 90),
#  ('seat', 90),
#  ('street', 90),
#  ('between', 89),
#  ('ribs', 89),
#  ('decent', 89),
#  ('room', 89),
#  ('disappointing.', 89),
#  ('favorite', 89),
#  ('way.', 88),
#  ('roll', 88),
#  ('cold.', 88),
#  ('40', 88),
#  ('telling', 88),
#  ('average', 87),
#  ('gotten', 87),
#  ('end', 87),
#  ('one.', 87),
#  ('seen', 87),
#  ('cafe', 87),
#  ('however', 86),
#  ('Italian', 86),
#  ('frozen', 86),
#  ('leaving', 85),
#  ('yet', 85),
#  ('taste.', 85),
#  ('incredibly', 85),
#  ('nor', 85),
#  ('total', 85),
#  ('slices', 85),
#  ('five', 85),
#  ('sad', 85),
#  ('pizza.', 85),
#  ('8', 85),
#  ('cannot', 84),
#  ('moved', 84),
#  ('parking', 84),
#  ('cake', 84),
#  ('issue', 84),
#  ('bag', 84),
#  ('totally', 83),
#  ('amazing', 83),
#  ('great.', 83),
#  ('Portland', 83),
#  ('us,', 83),
#  ('On', 83),
#  ('people.', 83),
#  ('(which', 83),
#  ('NEVER', 82),
#  ("there's", 82),
#  ('delicious', 82),
#  ('dog', 82),
#  ('had.', 82),
#  ('Our', 82),
#  ('others', 82),
#  ('hands', 82),
#  ('quick', 82),
#  ('change', 81),
#  ('knew', 81),
#  ('management', 81),
#  ('all,', 81),
#  ('line.', 81),
#  ('wine', 81),
#  ('sell', 81),
#  ('sauce.', 81),
#  ('upset', 81),
#  ('sandwiches.', 81),
#  ('kids', 80),
#  ('mistake', 80),
#  ('ingredients', 80),
#  ('cheese.', 80),
#  ('Cuban', 80),
#  ('refused', 79),
#  ('explained', 79),
#  ('biscuits', 79),
#  ('near', 79),
#  ('Sunday', 79),
#  ('Really', 79),
#  ('speak', 79),
#  ('support', 79),
#  ('obviously', 79),
#  ('size', 79),
#  ('unless', 78),
#  ('proceeded', 78),
#  ('better.', 78),
#  ('bill', 78),
#  ('bought', 78),
#  ('Do', 78),
#  ('Saturday', 78),
#  ('latte', 78),
#  ('informed', 77),
#  ('tiny', 77),
#  ('young', 77),
#  ('that,', 77),
#  ('feeling', 77),
#  ('multiple', 77),
#  ('la', 77),
#  ('head', 77),
#  ('short', 77),
#  ('warm', 77),
#  ('takes', 77),
#  ('pulled', 77),
#  ('please', 76),
#  ('returning', 76),
#  ('basically', 76),
#  ('in,', 76),
#  ('honestly', 76),
#  ('ordered.', 76),
#  ('ice', 76),
#  ('stood', 75),
#  ('chips', 75),
#  ('stay', 74),
#  ('worked', 74),
#  ('throw', 74),
#  ('this.', 74),
#  ('Service', 74),
#  ('potatoes', 74),
#  ('glass', 74),
#  ('bagels', 74),
#  ('eat.', 73),
#  ('tastes', 73),
#  ('yelp', 73),
#  ('paper', 73),
#  ('zero', 73),
#  ('cash', 73),
#  ('was.', 73),
#  ('hate', 73),
#  ("we're", 73),
#  ('Why', 73),
#  ('While', 73),
#  ('slow', 73),
#  ('Nothing', 73),
#  ('reading', 73),
#  ('up,', 73),
#  ('showed', 73),
#  ('gravy', 73),
#  ('expected', 73),
#  ('lettuce', 73),
#  ('truck', 72),
#  ('lunch.', 72),
#  ('show', 72),
#  ('credit', 72),
#  ('table,', 72),
#  ('portion', 72),
#  ('return.', 72),
#  ('using', 72),
#  ('toast', 72),
#  ('Go', 71),
#  ('wearing', 71),
#  ('Came', 71),
#  ('minutes,', 71),
#  ('realized', 71),
#  ('turkey', 71),
#  ('hype', 71),
#  ('Terrible', 71),
#  ('Worst', 71),
#  ('Got', 71),
#  ('coffee,', 71),
#  ('sent', 71),
#  ('(I', 71),
#  ('meals', 70),
#  ('meat.', 70),
#  ('dollars', 70),
#  ('too.', 70),
#  ('beans', 70),
#  ('running', 70),
#  ('negative', 70),
#  ('worse', 70),
#  ('available', 70),
#  ('25', 70),
#  ('bowl', 70),
#  ('hear', 69),
#  ('hoping', 69),
#  ('Now', 69),
#  ('French', 69),
#  ('yourself', 69),
#  ('for.', 69),
#  ('subs', 69),
#  ('website', 69),
#  ('milk', 69),
#  ('plate.', 68),
#  ('gets', 68),
#  ('wrong.', 68),
#  ('ran', 68),
#  ('turn', 68),
#  ('...', 68),
#  ('chance', 68),
#  ('ignored', 68),
#  ('missing', 67),
#  ('except', 67),
#  ('late', 67),
#  ('attention', 67),
#  ('quickly', 67),
#  ('today.', 66),
#  ('you,', 66),
#  ('salty', 66),
#  ('ago', 66),
#  ('greasy', 66),
#  ('situation', 66),
#  ('say,', 66),
#  ('disgusting', 66),
#  ('home.', 66),
#  ('thinking', 66),
#  ('price.', 66),
#  ('not.', 66),
#  ('ever.', 66),
#  ('nasty', 66),
#  ('de', 66),
#  ('okay', 66),
#  ('awful.', 66),
#  ('goes', 66),
#  ('Cafe', 66),
#  ('roast', 66),
#  ('review.', 66),
#  ('stuff', 66),
#  ('course', 65),
#  ('closing', 65),
#  ('mask', 65),
#  ('checked', 65),
#  ('sold', 65),
#  ('together', 65),
#  ('positive', 65),
#  ('move', 65),
#  ('expecting', 65),
#  ("Won't", 65),
#  ('horrible.', 65),
#  ('cause', 65),
#  ("hadn't", 64),
#  ('Once', 64),
#  ('soon', 64),
#  ('Good', 64),
#  ('certainly', 64),
#  ('red', 64),
#  ('servers', 64),
#  ('seating', 64),
#  ('New', 64),
#  ('months', 63),
#  ('Too', 63),
#  ('nearly', 63),
#  ('\n\nWe', 63),
#  ('cheap', 63),
#  ('pasta', 63),
#  ('finished', 63),
#  ('gluten', 63),
#  ('stated', 62),
#  ('box', 62),
#  ('highly', 62),
#  ('stomach', 62),
#  ('biscuit', 62),
#  ('set', 62),
#  ('fast', 62),
#  ('great,', 62),
#  ('clear', 62),
#  ('surprised', 62),
#  ('ruined', 62),
#  ('Would', 62),
#  ('bites', 62),
#  ('watched', 62),
#  ('tomato', 62),
#  ('case', 62),
#  ('list', 61),
#  ('plates', 61),
#  ('plain', 61),
#  ('day,', 61),
#  ('dont', 61),
#  ('times.', 61),
#  ('workers', 61),
#  ...]

# %%
### Visualization
plt.pyplot.hist(res_score,edgecolor='black',facecolor='blue', alpha=0.5)
review_score = review['stars_x']
plt.pyplot.bar(range(1,6),[review_score.value_counts()[1],review_score.value_counts()[2],review_score.value_counts()[3],review_score.value_counts()[4],review_score.value_counts()[5]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pn/hckqkf296kg0zy4dv62c5sk40000gn/T/ipykernel_76264/471849380.py in <module>
#       1 ### Visualization
# ----> 2 plt.pyplot.hist(res_score,edgecolor='black',facecolor='blue', alpha=0.5)
#       3 review_score = review['stars_x']
#       4 plt.pyplot.bar(range(1,6),[review_score.value_counts()[1],review_score.value_counts()[2],review_score.value_counts()[3],review_score.value_counts()[4],review_score.value_counts()[5]])
#
# NameError: name 'plt' is not defined
